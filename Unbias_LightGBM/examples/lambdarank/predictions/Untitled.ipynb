# %%
DFRSimilarityFactory = {"basicModel": ["Be", "G", "P", "D", "I(n)", "I(ne)", "I(F)"],
 "afterEffect": ["L", "B", "none"],
 "normalization": ["H1", "H2", "H3", "Z", "none"]}

IBSimilarityFactory = {"distribution" : ["LL", "SPL"],
                      "lambda": ["DF", "TTF"],
                       "normalization": ["H1", "H2", "H3", "Z", "none"]}

LMDirichletSimilarityFactory = {"mu": [ 2000]} # default

LMJelinekMercerSimilarityFactory = {"lambda": [0.7]}

DFISimilarityFactory = {"independenceMeasure": ["Standardized", "Saturated", "ChiSquared"]}

ClassicSimilarityFactory = {}

BM25SimilarityFactory = {"k1" : [1.2], "b": [0.75]} # defaults

SimilarityFactory = {"DFRSimilarityFactory": DFRSimilarityFactory,
                     "IBSimilarityFactory": IBSimilarityFactory,
                     "LMDirichletSimilarityFactory": LMDirichletSimilarityFactory,
                     "LMJelinekMercerSimilarityFactory" : LMJelinekMercerSimilarityFactory,
                     "DFISimilarityFactory" : DFISimilarityFactory,
                     "ClassicSimilarityFactory": ClassicSimilarityFactory,
                     "BM25SimilarityFactory": BM25SimilarityFactory}


from sklearn.model_selection import ParameterGrid
list(ParameterGrid(SimilarityFactory['DFRSimilarityFactory']))
# Out:
# [{'afterEffect': 'L', 'basicModel': 'Be', 'normalization': 'H1'},
#  {'afterEffect': 'L', 'basicModel': 'Be', 'normalization': 'H2'},
#  {'afterEffect': 'L', 'basicModel': 'Be', 'normalization': 'H3'},
#  {'afterEffect': 'L', 'basicModel': 'Be', 'normalization': 'Z'},
#  {'afterEffect': 'L', 'basicModel': 'Be', 'normalization': 'none'},
#  {'afterEffect': 'L', 'basicModel': 'G', 'normalization': 'H1'},
#  {'afterEffect': 'L', 'basicModel': 'G', 'normalization': 'H2'},
#  {'afterEffect': 'L', 'basicModel': 'G', 'normalization': 'H3'},
#  {'afterEffect': 'L', 'basicModel': 'G', 'normalization': 'Z'},
#  {'afterEffect': 'L', 'basicModel': 'G', 'normalization': 'none'},
#  {'afterEffect': 'L', 'basicModel': 'P', 'normalization': 'H1'},
#  {'afterEffect': 'L', 'basicModel': 'P', 'normalization': 'H2'},
#  {'afterEffect': 'L', 'basicModel': 'P', 'normalization': 'H3'},
#  {'afterEffect': 'L', 'basicModel': 'P', 'normalization': 'Z'},
# ...

# %%
# Out:
# [{'afterEffect': 'L', 'basicModel': 'Be', 'normalization': 'H1'},
#  {'afterEffect': 'L', 'basicModel': 'Be', 'normalization': 'H2'},
#  {'afterEffect': 'L', 'basicModel': 'Be', 'normalization': 'H3'},
#  {'afterEffect': 'L', 'basicModel': 'Be', 'normalization': 'Z'},
#  {'afterEffect': 'L', 'basicModel': 'Be', 'normalization': 'none'},
#  {'afterEffect': 'L', 'basicModel': 'G', 'normalization': 'H1'},
#  {'afterEffect': 'L', 'basicModel': 'G', 'normalization': 'H2'},
#  {'afterEffect': 'L', 'basicModel': 'G', 'normalization': 'H3'},
#  {'afterEffect': 'L', 'basicModel': 'G', 'normalization': 'Z'},
#  {'afterEffect': 'L', 'basicModel': 'G', 'normalization': 'none'},
#  {'afterEffect': 'L', 'basicModel': 'P', 'normalization': 'H1'},
#  {'afterEffect': 'L', 'basicModel': 'P', 'normalization': 'H2'},
#  {'afterEffect': 'L', 'basicModel': 'P', 'normalization': 'H3'},
#  {'afterEffect': 'L', 'basicModel': 'P', 'normalization': 'Z'},
# ...
